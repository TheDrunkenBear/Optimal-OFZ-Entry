# %% [markdown]
# <a href="https://colab.research.google.com/github/TheDrunkenBear/Optimal-OFZ-Entry/blob/master/MOEX_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Зависимости
import requests
import pandas as pd

# %%
def get_ofz_securities(i: int) -> tuple[pd.DataFrame, int]:
  """ get_securities
  Функция для получения списка ОФЗ фондового рынка облигаций.

  Args:
    i - индекс страницы.

  Returns:
    tuple(pd.DataFrame, int)
    Таблица облигаций и размер таблицы.
  """
  response_securities = requests.get(
      url="https://iss.moex.com/iss/securities.json",
      params={
          # Фондовый рынок
          "engine": "stock",
          # Рынок облигаций
          "market": "bonds",
          # Облигации Федерального займа
          "q": "ОФЗ",
          # Индекс страницы
          "start": i * 100
      }
  )

  response_status_code = response_securities.status_code

  if response_status_code == 200:
    securities = response_securities.json()["securities"]
    securities_data = pd.DataFrame(data=securities["data"], columns=securities["columns"])
  else:
    securities_data = pd.DataFrame()

  return securities_data, securities_data.shape[0]

# %%
i = 0  # индекс стартовой страницы
securities = []
while True:
  # Собираем полный список ОФЗ, торгуемых на Московской бирже
  securities_sample, securities_size = get_ofz_securities(i)
  if securities_size == 0:
    break

  securities.append(securities_sample)
  i += 1

# %%
# Объединяем полученные данные
securities_data = pd.concat(securities).reset_index()

# %%
display(securities_data.head(3))
# Out:
#    index         secid  shortname  regnumber                     name  \
# 0      0  SU26238RMFS4  ОФЗ 26238  26238RMFS  ОФЗ-ПД 26238 15/05/2041
# 1      1  SU26248RMFS3  ОФЗ 26248  26248RMFS    ОФЗ-ПД 26248 16/05/40
# 2      2  SU26247RMFS5  ОФЗ 26247  26247RMFS    ОФЗ-ПД 26247 11/05/39
#
#            isin  is_traded  emitent_id  \
# 0  RU000A1038V6          1        1228
# 1  RU000A108EH4          1        1228
# 2  RU000A108EF8          1        1228
#
#                                 emitent_title emitent_inn emitent_okpo  \
# 0  Министерство финансов Российской Федерации  7710168360         None
# 1  Министерство финансов Российской Федерации  7710168360         None
# 2  Министерство финансов Российской Федерации  7710168360         None
#
#        type        group primary_boardid marketprice_boardid
# 0  ofz_bond  stock_bonds            TQOB                TQOB
# 1  ofz_bond  stock_bonds            TQOB                TQOB
# 2  ofz_bond  stock_bonds            TQOB                TQOB
